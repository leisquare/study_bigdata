# %%
class Shape:
    def __init__(self,x=0,y=0):
        self.x=x
        self.y=y
    def __del__(self):
        print("소멸")
        
    def move(self, x, y):
        self.x+=x
        self.y+=y
        
    def __str__(self):
        return "좌표는 {},{}".format(self.x,self.y)
        
    def carc_area(self):
        raise exception("이 메소드는 반드시 구현되어야 합니다.")
        pass
    
    @staticmethod
    def that_(): 
        print("도형클래스 호출")

# %%
class Shape(Shape):
    __count=0;
    def __init__(self,x=0,y=0,width=0,height=0):
        Shape.__init__(self,x,y)
        self.width=width
        self.height=height
        Triangle._Triangle__count += 1
    def __del__(self):
        Triangle._Triangle__count -= 1 
        pass
    def carc_area(self):
        return "삼각형의 넓이는 {}".format(self.width*self.height*(1/2))
    def print_info(self):
        print("좌표는 {},{},길이는 {}, 높이는 {}".format(self.x,self.y,self.width,self.height))
    def __str__(self):
        return super().__str__() + " 길이는 {}, 높이는 {}".format(self.width,self.height)
    @classmethod
    def get_count(cls):
        return cls__count

# %%
t1=Triangle(0,0,5,4)
t2=Triangle(0,0,8,2)
print(t1)
print(t2)
# Out:
# 좌표는 0,0 길이는 5, 높이는 4
# 좌표는 0,0 길이는 8, 높이는 2

# %%
t1.carc_area()
# Out:
# '삼각형의 넓이는 10.0'

# %%
t2.print_info()
# Out:
# 좌표는 0,0,길이는 8, 높이는 2

# %%
t1=Triangle(0,0,5,4)
t2=Triangle(0,0,8,2)
t3=Triangle(0,0,9,10)
t4=Triangle(0,0,5,77)
print("객체 갯수:",Triangle.get_count())
# Out:
# 객체 갯수: 4

# %%
#연습문제 1번: 1
#연습문제 2번: 2
#연습문제 3번: 4
#연습문제 4번: 1
#연습문제 5번: 2
#연습문제 6번: 3?  #매개변수 수 같아야 함.
#연습문제 7번: 3
#연습문제 8번: 3번
#연습문제 9번: 2(매개변수 스트링)

# %%
class SomeClass:
    def method_a(self):
        print("method_a")
    @classmethod
    def method_b(cls):
        print("method_b")
    
obj=SomeClass()

# %%
SomeClass.method_b()

# %%
#서술형 9번
class Person:
    """서술형 9번문제"""
    def __init__(self,name="홍",gender='남'):
        self.name=name
        self.gender=gender
    def __str__(self):
        return "이름은:"+ self.name
    def __del__(self):
        pass 
    def print_info(self):
        print(self.name)

# %%
p = Person()
print(p)
# Out:
# 이름은:홍

# %%
dir(p)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'gender',
#  'name',
#  'print_info']

# %%
p.__dict__ #내가 선언한 아이들이 나옴(클래스의 멤버들)
# Out:
# {'name': '홍', 'gender': '남'}

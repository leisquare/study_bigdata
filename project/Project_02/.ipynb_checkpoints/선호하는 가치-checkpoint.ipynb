# %%
#시작 전 설정
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
# %config InlineBackend.figure_format='retina'
import pandas as pd
import numpy as np
#원하는 한글폰트 지정
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False) #Y축
#경고메세지 안보이게
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns

# %%
import pandas as pd
lvalues=pd.read_csv('E:/kim_jiwon/src/Project_02/data/선호하는_가치_20210412165024.csv',sep=',',encoding='cp949')
lvalues
# Out:
#     특성별(1)       특성별(2)          2017        2017.1        2017.2  \
# 0   특성별(1)       특성별(2)  일과 여가 중시 선호도  일과 여가 중시 선호도  일과 여가 중시 선호도
# 1   특성별(1)       특성별(2)   일을 매우 더 중시함      일을 더 중시함   일을 약간 더 중시함
# 2       전체           소계           3.4          13.4          15.2
# 3       성별           남자           4.1          15.8          16.9
# 4       성별           여자           2.6          10.6          13.2
# 5      연령별      만15-18세           1.8           7.9          12.6
# 6      연령별      만19-29세           3.9          12.8          15.3
# 7      연령별      만30-39세           3.3          15.6          15.7
# 8      연령별      만18-19세             -             -             -
# 9      연령별      만20-24세             -             -             -
# 10     연령별      만25-29세             -             -             -
# 11     연령별      만30-34세             -             -             -
# 12     지역별           서울           3.7          14.3          14.3
# ...

# %%
# 일단 시계열/문항/항목/전체만 남긴다.
# 전체전체
lvalues1=lvalues.iloc[0:3,2:]
lvalues1=lvalues1.T.reset_index()
lvalues1.columns=['년도','문항','항목','응답수치']
lvalues1["년도"]= lvalues1["년도"].apply(lambda x:int(x.split(".")[0]))
lvalues1.응답수치=lvalues1.응답수치.astype(float)
lvalues1
# Out:
#        년도             문항            항목  응답수치
# 0    2017   일과 여가 중시 선호도   일을 매우 더 중시함   3.4
# 1    2017   일과 여가 중시 선호도      일을 더 중시함  13.4
# 2    2017   일과 여가 중시 선호도   일을 약간 더 중시함  15.2
# 3    2017   일과 여가 중시 선호도   일과 여가 차이 없음  24.6
# 4    2017   일과 여가 중시 선호도  여가를 약간 더 중시함  19.5
# ..    ...            ...           ...   ...
# 107  2020  개인과 집단 중시 선호도  개인을 약간 더 중시함  23.8
# 108  2020  개인과 집단 중시 선호도  개인과 집단 차이 없음  34.2
# 109  2020  개인과 집단 중시 선호도  집단을 약간 더 중시함  13.9
# 110  2020  개인과 집단 중시 선호도     집단을 더 중시함   7.1
# 111  2020  개인과 집단 중시 선호도  집단을 매우 더 중시함   1.4
#
# [112 rows x 4 columns]

# %%
lvalues1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   년도      112 non-null    int64
#  1   문항      112 non-null    object
#  2   항목      112 non-null    object
#  3   응답수치    112 non-null    float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.6+ KB

# %%
#문항별로 묶고 항목별로 나눠야? 
sns.catplot(data=lvalues1, x="년도",y="응답수치", kind="point", col="문항", hue="항목",col_wrap=1,
                      height=3, aspect=1, linewidth=2,ci=None) 

plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
#plt.savefig('E:/kim_jiwon/src/project_02/img/주관적_정신건강_수준_문항별항목별.png')

# %%
plt.title('선호하는 가치_일과 여가')
sns.pointplot(data=lvalues1[lvalues1["문항"]=='일과 여가 중시 선호도'], x="년도",y="응답수치", kind="bar", col="문항", hue="항목",col_wrap=1,
                      height=3, aspect=3, linewidth=2,ci=None) # aspect은 세로:가로가 1:5
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)

plt.savefig('E:/kim_jiwon/src/project_02/img/선호가치_일과 여가.png')

# %%
plt.title('선호하는 가치_현실과 이상')
sns.pointplot(data=lvalues1[lvalues1["문항"]=='현실과 이상 중시 선호도'], x="년도",y="응답수치", kind="bar", col="문항", hue="항목",col_wrap=1,
                      height=3, aspect=3, linewidth=2,ci=None) # aspect은 세로:가로가 1:5
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/선호가치_현실과 이상.png')

# %%
plt.title('선호하는 가치_결과와 과정')
sns.pointplot(data=lvalues1[lvalues1["문항"]=='결과와 과정 중시 선호도'], x="년도",y="응답수치", kind="bar", col="문항", hue="항목",col_wrap=1,
                      height=3, aspect=3, linewidth=2,ci=None) # aspect은 세로:가로가 1:5
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/선호가치_결과와 과정.png')

# %%
plt.title('선호하는 가치_개인과 집단')
sns.pointplot(data=lvalues1[lvalues1["문항"]=='개인과 집단 중시 선호도'], x="년도",y="응답수치", kind="bar", col="문항", hue="항목",col_wrap=1,
                      height=3, aspect=3, linewidth=2,ci=None) # aspect은 세로:가로가 1:5
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/선호가치_개인과 집단.png')

# %%
plt.title('선호하는 가치_일과 여가')
sns.pointplot(data=lvalues1[lvalues1["문항"]=='일과 여가 중시 선호도'], x="년도",y="응답수치", kind="bar", col="문항", hue="항목",col_wrap=1,
                      height=3, aspect=3, linewidth=2,ci=None) # aspect은 세로:가로가 1:5
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/선호가치_일과 여가.png')

# %%
#시작 전 설정
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
# %config InlineBackend.figure_format='retina'
import pandas as pd
import numpy as np
#원하는 한글폰트 지정
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False) #Y축
#경고메세지 안보이게
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns

# %%
import pandas as pd
data1=pd.read_csv('E:/kim_jiwon/src/Project_02/data/가구당_월평균_가계지출__전국_1인이상__20210412160942.csv',sep=',',encoding='cp949')
data2=pd.read_csv('E:/kim_jiwon/src/Project_02/data/가구당_월평균_가계수지__전국_1인이상__20210412161103.csv',sep=',',encoding='cp949')

data=pd.concat([data1,data2.iloc[:,1:]],axis=1)
data
#data2.iloc[:,1:]
# Out:
#              가계지출항목별(1)     2017    2017.1   2017.2     2017.3   2017.4  \
# 0            가계지출항목별(1)     전체가구  전체가구 중위값    근로자가구  근로자가구 중위값   근로자외가구
# 1              가구원수 (명)     2.46         -     2.60          -     2.30
# 2             가구주연령 (세)    51.57         -    46.27          -    57.87
# 3              가구분포 (%)   100.00         -    54.30          -    45.70
# 4              가계지출 (원)  3316143   2765253  3785788    3271484  2758150
# 5              소비지출 (원)  2556823   2141691  2844461    2428709  2215077
# 6    01.식료품 · 비주류음료 (원)   360273    310500   359328     317880   361395
# 7        02.주류 · 담배 (원)    34813     28000    39292      30600    29491
# 8        03.의류 · 신발 (원)   159018    115000   182545     131800   131066
# 9   04.주거 · 수도 · 광열 (원)   282999    207090   296169     216240   267352
# 10  05.가정용품 · 가사서비스 (원)   112030     56553   126770      63250    94517
# 11            06.보건 (원)   181796     82800   178218      84500   186048
# ...

# %%
setting_index=data.T.reset_index().iloc[:,0].apply(lambda x:str(x.split(".")[0]))

# %%
setting_index.name=""

# %%
test1=data.T

test1
# Out:
#                     0         1          2         3         4         5   \
# 가계지출항목별(1)  가계지출항목별(1)  가구원수 (명)  가구주연령 (세)  가구분포 (%)  가계지출 (원)  소비지출 (원)
# 2017              전체가구      2.46      51.57    100.00   3316143   2556823
# 2017.1        전체가구 중위값         -          -         -   2765253   2141691
# 2017.2           근로자가구      2.60      46.27     54.30   3785788   2844461
# 2017.3       근로자가구 중위값         -          -         -   3271484   2428709
# 2017.4          근로자외가구      2.30      57.87     45.70   2758150   2215077
# 2017.5      근로자외가구 중위값         -          -         -   2156030   1731460
# 2018              전체가구      2.43      51.83    100.00   3326764   2537641
# 2018.1        전체가구 중위값         -          -         -   2796479   2148513
# 2018.2           근로자가구      2.56      46.70     56.16   3770474   2805347
# 2018.3       근로자가구 중위값         -          -         -   3254766   2418767
# 2018.4          근로자외가구      2.27      58.40     43.84   2758458   2194763
# ...

# %%
test1.iloc[0,0]='가계지출항목별'

# %%
data=test1.set_index(setting_index)
#인덱스네임변경
data.rename(index = {'가계지출항목별(1)':'년도'}, inplace = True)

data
# Out:
#               0         1          2         3         4         5   \
#
# 년도       가계지출항목별  가구원수 (명)  가구주연령 (세)  가구분포 (%)  가계지출 (원)  소비지출 (원)
# 2017        전체가구      2.46      51.57    100.00   3316143   2556823
# 2017    전체가구 중위값         -          -         -   2765253   2141691
# 2017       근로자가구      2.60      46.27     54.30   3785788   2844461
# 2017   근로자가구 중위값         -          -         -   3271484   2428709
# 2017      근로자외가구      2.30      57.87     45.70   2758150   2215077
# 2017  근로자외가구 중위값         -          -         -   2156030   1731460
# 2018        전체가구      2.43      51.83    100.00   3326764   2537641
# 2018    전체가구 중위값         -          -         -   2796479   2148513
# 2018       근로자가구      2.56      46.70     56.16   3770474   2805347
# 2018   근로자가구 중위값         -          -         -   3254766   2418767
# 2018      근로자외가구      2.27      58.40     43.84   2758458   2194763
# 2018  근로자외가구 중위값         -          -         -   2213731   1752376
# ...

# %% [markdown]
# data_1=data.iloc[0 ,:].to_frame().T
# data_2=data.iloc[4:,:]
# data_m=pd.concat([data_1,data_2],axis=0)
# data_m

# %%
data_1=data.iloc[:,0]
data_2=data.iloc[:,4:]
data_m=pd.concat([data_1,data_2],axis=1)
data_m=data_m.reset_index()
data_m
# Out:
#                    0         4         5                   6               7  \
# 0     년도     가계지출항목별  가계지출 (원)  소비지출 (원)  01.식료품 · 비주류음료 (원)  02.주류 · 담배 (원)
# 1   2017        전체가구   3316143   2556823              360273           34813
# 2   2017    전체가구 중위값   2765253   2141691              310500           28000
# 3   2017       근로자가구   3785788   2844461              359328           39292
# 4   2017   근로자가구 중위값   3271484   2428709              317880           30600
# 5   2017      근로자외가구   2758150   2215077              361395           29491
# 6   2017  근로자외가구 중위값   2156030   1731460              300040           24000
# 7   2018        전체가구   3326764   2537641              366672           35028
# 8   2018    전체가구 중위값   2796479   2148513              317220           29800
# 9   2018       근로자가구   3770474   2805347              363366           38190
# 10  2018   근로자가구 중위값   3254766   2418767              320390           32720
# ...

# %%
a=data_m.iloc[0,:]
data_m.columns=a
data_m_1=data_m.iloc[1:,]
data_m_1
# Out:
# 0     년도     가계지출항목별 가계지출 (원) 소비지출 (원) 01.식료품 · 비주류음료 (원) 02.주류 · 담배 (원)  \
# 1   2017        전체가구  3316143  2556823             360273          34813
# 2   2017    전체가구 중위값  2765253  2141691             310500          28000
# 3   2017       근로자가구  3785788  2844461             359328          39292
# 4   2017   근로자가구 중위값  3271484  2428709             317880          30600
# 5   2017      근로자외가구  2758150  2215077             361395          29491
# 6   2017  근로자외가구 중위값  2156030  1731460             300040          24000
# 7   2018        전체가구  3326764  2537641             366672          35028
# 8   2018    전체가구 중위값  2796479  2148513             317220          29800
# 9   2018       근로자가구  3770474  2805347             363366          38190
# 10  2018   근로자가구 중위값  3254766  2418767             320390          32720
# 11  2018      근로자외가구  2758458  2194763             370906          30978
# 12  2018  근로자외가구 중위값  2213731  1752376             313330          24680
# ...

# %%
test2=data_m[data_m["가계지출항목별"]=='전체가구']

# %%
test2=test2.reset_index(drop=True)
test2
# Out:
# 0    년도 가계지출항목별 가계지출 (원) 소비지출 (원) 01.식료품 · 비주류음료 (원) 02.주류 · 담배 (원)  \
# 0  2017    전체가구  3316143  2556823             360273          34813
# 1  2018    전체가구  3326764  2537641             366672          35028
# 2  2019    전체가구  3329804  2456678             332558          35802
# 3  2020    전체가구  3239681  2400123             381056          37531
#
# 0 03.의류 · 신발 (원) 04.주거 · 수도 · 광열 (원) 05.가정용품 · 가사서비스 (원) 06.보건 (원) 07.교통 (원)  \
# 0         159018              282999              112030    181796    369150
# 1         152206              285461              117115    191120    348808
# 2         138180              276589              115323    202279    295974
# 3         118085              285822              126729    220558    288848
#
# 0 08.통신 (원) 09.오락 · 문화 (원) 10.교육 (원) 11.음식 · 숙박 (원) 12.기타상품 · 서비스 (원)  \
# 0    137838         174693    188343         354158            201712
# 1    134107         191772    173372         349699            192282
# ...

# %%
#test2 형변환


#test2.astype(int).dtypes
#test2[['가계지출 (원)', '비소비지출 (원)']] = test2[['가계지출 (원)', '비소비지출 (원)']].apply(pd.to_numeric)


test3 = test2.infer_objects()
#test3 = test2.astype(float)
test3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   년도                   4 non-null      object
#  1   가계지출항목별              4 non-null      object
#  2   가계지출 (원)             4 non-null      object
#  3   소비지출 (원)             4 non-null      object
#  4   01.식료품 · 비주류음료 (원)   4 non-null      object
#  5   02.주류 · 담배 (원)       4 non-null      object
#  6   03.의류 · 신발 (원)       4 non-null      object
#  7   04.주거 · 수도 · 광열 (원)  4 non-null      object
#  8   05.가정용품 · 가사서비스 (원)  4 non-null      object
#  9   06.보건 (원)            4 non-null      object
#  10  07.교통 (원)            4 non-null      object
#  11  08.통신 (원)            4 non-null      object
#  12  09.오락 · 문화 (원)       4 non-null      object
#  13  10.교육 (원)            4 non-null      object
#  14  11.음식 · 숙박 (원)       4 non-null      object
# ...

# %%
test3[['가계지출 (원)', '소비지출 (원)','01.식료품 · 비주류음료 (원)','02.주류 · 담배 (원)','03.의류 · 신발 (원)','04.주거 · 수도 · 광열 (원)','05.가정용품 · 가사서비스 (원)','06.보건 (원)','07.교통 (원)','08.통신 (원)','09.오락 · 문화 (원)','10.교육 (원)','11.음식 · 숙박 (원)','12.기타상품 · 서비스 (원)','비소비지출 (원)']]=test3[['가계지출 (원)', '소비지출 (원)','01.식료품 · 비주류음료 (원)','02.주류 · 담배 (원)','03.의류 · 신발 (원)','04.주거 · 수도 · 광열 (원)','05.가정용품 · 가사서비스 (원)','06.보건 (원)','07.교통 (원)','08.통신 (원)','09.오락 · 문화 (원)','10.교육 (원)','11.음식 · 숙박 (원)','12.기타상품 · 서비스 (원)','비소비지출 (원)']].astype(int)
test3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   년도                   4 non-null      object
#  1   가계지출항목별              4 non-null      object
#  2   가계지출 (원)             4 non-null      int32
#  3   소비지출 (원)             4 non-null      int32
#  4   01.식료품 · 비주류음료 (원)   4 non-null      int32
#  5   02.주류 · 담배 (원)       4 non-null      int32
#  6   03.의류 · 신발 (원)       4 non-null      int32
#  7   04.주거 · 수도 · 광열 (원)  4 non-null      int32
#  8   05.가정용품 · 가사서비스 (원)  4 non-null      int32
#  9   06.보건 (원)            4 non-null      int32
#  10  07.교통 (원)            4 non-null      int32
#  11  08.통신 (원)            4 non-null      int32
#  12  09.오락 · 문화 (원)       4 non-null      int32
#  13  10.교육 (원)            4 non-null      int32
#  14  11.음식 · 숙박 (원)       4 non-null      int32
# ...

# %%
fig=plt.figure(figsize=(10,8))
ax = fig.add_axes([0.1,0.1,0.7,0.7])
plt.plot("년도", "가계지출 (원)",data=test3,linewidth=2)
plt.plot("년도", "소비지출 (원)",data=test3,linewidth=1 )

ax.set_title('가구당_연평균_가계지수_가계지출과 소비지출', fontsize=20)
ax.set_xlabel('년도')
ax.set_ylabel('계수')


ax.tick_params(axis='x',labelsize=15,rotation=45)
ax.tick_params(axis='y',labelsize=15)
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)

plt.savefig('E:/kim_jiwon/src/project_02/graph/가구당_연평균_가계지수_가계지출과 소비지출.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-387f0d67a1c6> in <module>
#      13 plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
#      14
# ---> 15 plt.savefig('E:/kim_jiwon/src/project_02/img/가구당_연평균_가계지수_가계지출과 소비지출.png')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ...

# %%
fig=plt.figure(figsize=(10,8))
ax = fig.add_axes([0.1,0.1,0.7,0.7])





ax.set_title('가구당_연평균_가계지수_분야별', fontsize=20)
ax.set_xlabel('년도')
ax.set_ylabel('계수')

ax.tick_params(axis='x',labelsize=15,rotation=45)
ax.tick_params(axis='y',labelsize=15)
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)

plt.savefig('E:/kim_jiwon/src/project_02/graph/가구당_연평균_가계지수_분야별.png')

# %%
fig=plt.figure(figsize=(10,8))
ax = fig.add_axes([0.1,0.1,0.7,0.7])

plt.plot("년도", "01.식료품 · 비주류음료 (원)",data=test3,linewidth=3,color="red")
plt.plot("년도", "02.주류 · 담배 (원)",data=test3,linewidth=1 )
plt.plot("년도", "03.의류 · 신발 (원)",data=test3,linewidth=1 )
plt.plot("년도", "04.주거 · 수도 · 광열 (원)",data=test3,linewidth=1 )
plt.plot("년도", "05.가정용품 · 가사서비스 (원)",data=test3,linewidth=1 )
plt.plot("년도", "06.보건 (원)",data=test3,linewidth=1 )
plt.plot("년도", "07.교통 (원)",data=test3,linewidth=1 )
plt.plot("년도", "08.통신 (원)",data=test3,linewidth=1 )
plt.plot("년도", "09.오락 · 문화 (원)",data=test3,linewidth=1 )
plt.plot("년도", "10.교육 (원)",data=test3,linewidth=3 )
plt.plot("년도", "11.음식 · 숙박 (원)",data=test3,linewidth=3 )
plt.plot("년도", "12.기타상품 · 서비스 (원)",data=test3,linewidth=1 )
#plt.plot("년도", "비소비지출 (원)",data=test2,linewidth=1 )

ax.set_title('가구당 분야별 월평균 소비지출액', fontsize=20)
ax.set_xlabel('년도')
ax.set_ylabel('소비지출액')

ax.tick_params(axis='x',labelsize=15,rotation=45)
ax.tick_params(axis='y',labelsize=15)
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)

plt.savefig('E:/kim_jiwon/src/project_02/graph/가구당_월평균_가계지수_분야별.png')

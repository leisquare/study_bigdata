# %%
#시작 전 설정
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
# %config InlineBackend.figure_format='retina'
import pandas as pd
import numpy as np
#원하는 한글폰트 지정
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False) #Y축
#경고메세지 안보이게
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns

# %%
import pandas as pd
inside=pd.read_csv('E:/kim_jiwon/src/Project_02/data/외출을_하지_않는_상태의_지속_기간_정도_및_계기_20210412161948.csv',sep=',',encoding='cp949')
inside
# Out:
#     특성별(1)       특성별(2)          2017        2017.1        2017.2  \
# 0   특성별(1)       특성별(2)  외출을 하지 않은 기간  외출을 하지 않은 기간  외출을 하지 않은 기간
# 1   특성별(1)       특성별(2)        6개월 미만  6개월 이상-1년 미만   1년 이상-3년 미만
# 2       전체           소계          18.4          17.9          36.5
# 3       성별           남자          43.0          14.0          39.6
# 4       성별           여자          12.4          18.9          35.8
# 5      연령별      만15-18세             -             -             -
# 6      연령별      만19-29세          30.0          18.7          35.0
# 7      연령별      만30-39세          11.3          17.5          37.4
# 8      연령별      만18-19세             -             -             -
# 9      연령별      만20-24세             -             -             -
# 10     연령별      만25-29세             -             -             -
# 11     연령별      만30-34세             -             -             -
# 12     지역별           서울          13.5          20.3          47.6
# ...

# %%
inside1=inside.iloc[0:3,2:]
inside1=inside1.T.reset_index()
inside1.columns=['년도','문항','항목','응답수치']
inside1["년도"]= inside1["년도"].apply(lambda x:int(x.split(".")[0]))
inside1.응답수치=inside1.응답수치.astype(float)
inside1
# Out:
#       년도              문항               항목  응답수치
# 0   2017    외출을 하지 않은 기간           6개월 미만  18.4
# 1   2017    외출을 하지 않은 기간     6개월 이상-1년 미만  17.9
# 2   2017    외출을 하지 않은 기간      1년 이상-3년 미만  36.5
# 3   2017    외출을 하지 않은 기간      3년 이상-5년 미만  16.6
# 4   2017    외출을 하지 않은 기간      5년 이상-7년 미만   6.0
# 5   2017    외출을 하지 않은 기간            7년 이상   4.7
# 6   2017  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로   3.8
# 7   2017  외출을 하지 않게 된 계기      취업이 잘되지 않아서  17.9
# 8   2017  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서  10.1
# 9   2017  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서   4.6
# 10  2017  외출을 하지 않게 된 계기      임신이나 출산 때문에  61.3
# 11  2017  외출을 하지 않게 된 계기               기타   2.2
# 12  2018    외출을 하지 않은 기간           6개월 미만  23.5
# 13  2018    외출을 하지 않은 기간     6개월 이상-1년 미만  23.8
# 14  2018    외출을 하지 않은 기간      1년 이상-3년 미만   9.1
# 15  2018    외출을 하지 않은 기간      3년 이상-5년 미만  25.5
# 16  2018    외출을 하지 않은 기간      5년 이상-7년 미만  11.3
# 17  2018    외출을 하지 않은 기간            7년 이상   6.9
# 18  2018  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로   5.8
# ...

# %%
inside_l=inside1[inside1['문항']=='외출을 하지 않은 기간']
inside_l
inside_r=inside1[inside1['문항']=='외출을 하지 않게 된 계기']
inside_r
# Out:
#       년도              문항               항목  응답수치
# 6   2017  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로   3.8
# 7   2017  외출을 하지 않게 된 계기      취업이 잘되지 않아서  17.9
# 8   2017  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서  10.1
# 9   2017  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서   4.6
# 10  2017  외출을 하지 않게 된 계기      임신이나 출산 때문에  61.3
# 11  2017  외출을 하지 않게 된 계기               기타   2.2
# 18  2018  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로   5.8
# 19  2018  외출을 하지 않게 된 계기      취업이 잘되지 않아서  33.0
# 20  2018  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서  17.7
# 21  2018  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서   4.3
# 22  2018  외출을 하지 않게 된 계기      임신이나 출산 때문에  37.2
# 23  2018  외출을 하지 않게 된 계기               기타   1.9
# 30  2019  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로   3.1
# 31  2019  외출을 하지 않게 된 계기      취업이 잘되지 않아서  22.2
# 32  2019  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서   2.3
# 33  2019  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서   1.8
# 34  2019  외출을 하지 않게 된 계기      임신이나 출산 때문에  54.4
# 35  2019  외출을 하지 않게 된 계기               기타  16.3
# 42  2020  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로   5.1
# ...

# %%
plt.title('외출하지 않은 기간: 전체')
save2=sns.pointplot(data=inside_l, x="년도",y="응답수치", kind="point", hue="항목",ci=None) # aspect은 세로:가로가 1:5
save2
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)

plt.savefig('E:/kim_jiwon/src/project_02/img/외출하지 않은 기간.png')

# %%
plt.title('외출하지 않게 된 계기: 전체')
save2=sns.pointplot(data=inside_r, x="년도",y="응답수치", kind="point", hue="항목",ci=None) # aspect은 세로:가로가 1:5
save2
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)

plt.savefig('E:/kim_jiwon/src/project_02/img/외출하지 않게 된 계기_전체.png')

# %%
inside2=inside.iloc[[0,1,3,4],2:]
inside2=inside2.T.reset_index()
inside2.columns=['년도','문항','항목','남','녀']
inside2["년도"]= inside2["년도"].apply(lambda x:int(x.split(".")[0]))
inside2.남=inside2.남.astype(float)
inside2.녀=inside2.녀.astype(float)
inside2
# Out:
#       년도              문항               항목     남     녀
# 0   2017    외출을 하지 않은 기간           6개월 미만  43.0  12.4
# 1   2017    외출을 하지 않은 기간     6개월 이상-1년 미만  14.0  18.9
# 2   2017    외출을 하지 않은 기간      1년 이상-3년 미만  39.6  35.8
# 3   2017    외출을 하지 않은 기간      3년 이상-5년 미만   3.4  19.7
# 4   2017    외출을 하지 않은 기간      5년 이상-7년 미만   0.0   7.4
# 5   2017    외출을 하지 않은 기간            7년 이상   0.0   5.8
# 6   2017  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로  14.3   1.3
# 7   2017  외출을 하지 않게 된 계기      취업이 잘되지 않아서  40.2  12.5
# 8   2017  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서  22.1   7.2
# 9   2017  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서  12.1   2.8
# 10  2017  외출을 하지 않게 된 계기      임신이나 출산 때문에   0.0  76.1
# 11  2017  외출을 하지 않게 된 계기               기타  11.3   0.0
# 12  2018    외출을 하지 않은 기간           6개월 미만  39.2  13.6
# 13  2018    외출을 하지 않은 기간     6개월 이상-1년 미만  13.9  29.9
# 14  2018    외출을 하지 않은 기간      1년 이상-3년 미만   8.9   9.1
# 15  2018    외출을 하지 않은 기간      3년 이상-5년 미만  29.3  23.2
# ...

# %%
inside_l2=inside2[inside2['문항']=='외출을 하지 않은 기간']
inside_l2
inside_r2=inside2[inside2['문항']=='외출을 하지 않게 된 계기']
inside_r2
# Out:
#       년도              문항               항목     남     녀
# 6   2017  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로  14.3   1.3
# 7   2017  외출을 하지 않게 된 계기      취업이 잘되지 않아서  40.2  12.5
# 8   2017  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서  22.1   7.2
# 9   2017  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서  12.1   2.8
# 10  2017  외출을 하지 않게 된 계기      임신이나 출산 때문에   0.0  76.1
# 11  2017  외출을 하지 않게 된 계기               기타  11.3   0.0
# 18  2018  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로  15.2   0.0
# 19  2018  외출을 하지 않게 된 계기      취업이 잘되지 않아서  47.1  24.3
# 20  2018  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서  24.3  13.6
# 21  2018  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서   8.6   1.7
# 22  2018  외출을 하지 않게 된 계기      임신이나 출산 때문에   0.0  60.4
# 23  2018  외출을 하지 않게 된 계기               기타   4.9   0.0
# 30  2019  외출을 하지 않게 된 계기  학업중단이나 대학진학 실패로   5.1   2.4
# 31  2019  외출을 하지 않게 된 계기      취업이 잘되지 않아서  71.3   4.5
# 32  2019  외출을 하지 않게 된 계기    인간관계가 잘되지 않아서   2.1   2.4
# 33  2019  외출을 하지 않게 된 계기  장애가 있거나 몸이 불편해서   2.3   1.6
# ...

# %%
plt.title('외출하지 않은 기간: 남성')
save_male=sns.pointplot(data=inside_l2, x="년도",y="남", kind="point", hue="항목",ci=None) # aspect은 세로:가로가 1:5
save_male

plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/외출하지 않은 기간_남성.png')

# %%
plt.title('외출하지 않은 기간: 여성')
save_female=sns.pointplot(data=inside_l2, x="년도",y="녀", kind="point", hue="항목",ci=None)
save_female
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/외출하지 않은 기간_여성.png')

# %%
plt.title('외출하지 않은 계기: 남성')
reason_male=sns.pointplot(data=inside_r2, x="년도",y="남", kind="point", hue="항목",ci=None)
reason_male
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/외출하지 않은 계기_남성.png')

# %%
plt.title('외출하지 않은 계기: 여성')
reason_female=sns.pointplot(data=inside_r2, x="년도",y="녀", kind="point", hue="항목",ci=None)
reason_female
plt.legend(bbox_to_anchor=(1.01,1.0),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/외출하지 않은 계기_여성.png')

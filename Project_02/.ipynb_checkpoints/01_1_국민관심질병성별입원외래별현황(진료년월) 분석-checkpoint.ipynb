# %%
#시작 전 설정
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
# %config InlineBackend.figure_format='retina'
import pandas as pd
import numpy as np
#원하는 한글폰트 지정
plt.rc("font",family="Malgun Gothic")
plt.rc("axes",unicode_minus=False) #Y축
#경고메세지 안보이게
import warnings
warnings.filterwarnings(action='ignore')
import seaborn as sns
import folium #지도시각화를 위한

# %%
cond1.T
# Out:
# 성별구분     NaN  계   남   남   남   여   여   여
# 입원외래구분  진료년월  계  소계  외래  입원  소계  외래  입원

# %%
import pandas as pd
cond=pd.read_excel('E:/kim_jiwon/src/Project_02/data/1_국민관심질병성별입원외래별현황(진료년월).xls')
cond.columns=cond.loc[6,:]
cond1=cond.iloc[5,:].to_frame()
cond2=cond.iloc[7:14,:]
cond3=pd.concat([cond1.T,cond2],axis=0)

cond3
# Out:
# 6    항목 성별구분 입원외래구분        환자수       내원일수       청구건수    요양급여비용총액      보험자부담금  \
# 5   NaN  NaN   진료년월  2019년 01월  2019년 01월  2019년 01월   2019년 01월   2019년 01월
# 7   우울증    계      계    306,876    548,405    499,271  31,996,122  23,880,395
# 8   우울증    남     소계     98,519    182,326    158,790  10,902,528   8,083,843
# 9   우울증    남     외래     97,539    156,833    157,364   8,193,681   6,041,438
# 10  우울증    남     입원      1,263     25,493      1,426   2,708,846   2,042,405
# 11  우울증    여     소계    208,357    366,079    340,481  21,093,595  15,796,551
# 12  우울증    여     외래    207,345    337,374    338,475  17,288,587  12,912,080
# 13  우울증    여     입원      1,619     28,705      2,006   3,805,008   2,884,471
#
# 6         환자수       내원일수  ...        환자수       내원일수       청구건수    요양급여비용총액  \
# 5   2019년 02월  2019년 02월  ...  2020년 07월  2020년 07월  2020년 07월   2020년 07월
# 7     284,101    454,089  ...    347,030    612,379    572,521  37,225,321
# 8      91,918    152,914  ...    109,810    196,445    177,712  12,145,642
# 9      91,000    131,484  ...    108,989    176,468    176,481   9,816,701
# 10      1,112     21,430  ...      1,020     19,977      1,231   2,328,942
# 11    192,183    301,175  ...    237,220    415,934    394,809  25,079,679
# 12    191,281    277,814  ...    236,325    392,866    392,906  21,823,288
# 13      1,310     23,361  ...      1,430     23,068      1,903   3,256,390
#
# 6       보험자부담금        환자수       내원일수       청구건수    요양급여비용총액      보험자부담금
# 5    2020년 07월  2020년 08월  2020년 08월  2020년 08월   2020년 08월   2020년 08월
# 7   28,362,139    335,517    556,163    518,648  33,210,825  25,274,579
# 8    9,185,359    106,387    179,538    162,289  10,828,993   8,188,274
# 9    7,428,035    105,622    161,016    161,100   8,923,061   6,754,788
# 10   1,757,324        970     18,522      1,189   1,905,932   1,433,485
# 11  19,176,781    229,130    376,625    356,359  22,381,833  17,086,305
# 12  16,695,557    228,324    354,540    354,682  19,623,837  14,993,148
# 13   2,481,224      1,276     22,085      1,677   2,757,995   2,093,156
#
# [8 rows x 103 columns]

# %%
cond=cond3
cond.reset_index().iloc[:,2:]
#cond.환자수
cond1=cond[['성별구분','입원외래구분']]
cond2=cond.환자수
cond3=pd.concat([cond1,cond2],axis=1)
cond3.index.name = None
cond3.columns = [''] * len(cond3.columns)
cond3
# Out:
#                                                                       \
# 5   NaN  진료년월  2019년 01월  2019년 02월  2019년 03월  2019년 04월  2019년 05월
# 7     계     계    306,876    284,101    301,289    310,462    315,135
# 8     남    소계     98,519     91,918     97,298    100,294    102,198
# 9     남    외래     97,539     91,000     96,362     99,313    101,178
# 10    남    입원      1,263      1,112      1,157      1,250      1,324
# 11    여    소계    208,357    192,183    203,991    210,168    212,937
# 12    여    외래    207,345    191,281    203,119    209,239    211,947
# 13    여    입원      1,619      1,310      1,377      1,530      1,601
#
#                                      ...                                   \
# 5   2019년 06월  2019년 07월  2019년 08월  ...  2019년 11월  2019년 12월  2020년 01월
# 7     306,275    324,337    320,453  ...    325,566    328,764    323,442
# 8      98,845    104,577    103,582  ...    104,088    104,970    103,532
# 9      97,830    103,565    102,585  ...    103,090    104,010    102,571
# 10      1,270      1,317      1,247  ...      1,245      1,171      1,222
# 11    207,430    219,760    216,871  ...    221,478    223,794    219,910
# 12    206,455    218,745    215,868  ...    220,468    222,807    218,901
# 13      1,586      1,696      1,583  ...      1,651      1,594      1,566
#
#                                                                       \
# 5   2020년 02월  2020년 03월  2020년 04월  2020년 05월  2020년 06월  2020년 07월
# 7     314,895    317,522    319,785    331,269    338,264    347,030
# 8     101,145    101,578    101,660    105,185    107,249    109,810
# 9     100,289    100,784    100,950    104,406    106,437    108,989
# 10      1,042        933        881        970      1,024      1,020
# 11    213,750    215,944    218,125    226,084    231,015    237,220
# 12    212,929    215,181    217,371    225,297    230,211    236,325
# 13      1,207      1,100      1,094      1,197      1,307      1,430
#
#
# 5   2020년 08월
# 7     335,517
# 8     106,387
# 9     105,622
# 10        970
# 11    229,130
# 12    228,324
# 13      1,276
#
# [8 rows x 22 columns]

# %%
cond3.columns=cond3.iloc[0,]
cond4=cond3.iloc[1:,].reset_index().iloc[:,1:]
#cond4.iloc[1:,1:].replace(',','',regex=True,replale)
cond4.replace(',','', regex=True, inplace=True)
cond4.iloc[1:,2:].astype(int)
cond4
# cond4 = 우울증에 걸린 사람들 수
# Out:
# 5 NaN 진료년월 2019년 01월 2019년 02월 2019년 03월 2019년 04월 2019년 05월 2019년 06월  \
# 0   계    계    306876    284101    301289    310462    315135    306275
# 1   남   소계     98519     91918     97298    100294    102198     98845
# 2   남   외래     97539     91000     96362     99313    101178     97830
# 3   남   입원      1263      1112      1157      1250      1324      1270
# 4   여   소계    208357    192183    203991    210168    212937    207430
# 5   여   외래    207345    191281    203119    209239    211947    206455
# 6   여   입원      1619      1310      1377      1530      1601      1586
#
# 5 2019년 07월 2019년 08월  ... 2019년 11월 2019년 12월 2020년 01월 2020년 02월 2020년 03월  \
# 0    324337    320453  ...    325566    328764    323442    314895    317522
# 1    104577    103582  ...    104088    104970    103532    101145    101578
# 2    103565    102585  ...    103090    104010    102571    100289    100784
# 3      1317      1247  ...      1245      1171      1222      1042       933
# 4    219760    216871  ...    221478    223794    219910    213750    215944
# 5    218745    215868  ...    220468    222807    218901    212929    215181
# 6      1696      1583  ...      1651      1594      1566      1207      1100
#
# 5 2020년 04월 2020년 05월 2020년 06월 2020년 07월 2020년 08월
# 0    319785    331269    338264    347030    335517
# 1    101660    105185    107249    109810    106387
# 2    100950    104406    106437    108989    105622
# 3       881       970      1024      1020       970
# 4    218125    226084    231015    237220    229130
# 5    217371    225297    230211    236325    228324
# 6      1094      1197      1307      1430      1276
#
# [7 rows x 22 columns]

# %%
#cond4.columns[0].rename
cond4.rename(columns={np.nan:'성별', '진료년월':'유형'},inplace=True)
cond4.index.name = None
cond4.set_index('성별')
# Out:
# 5   유형 2019년 01월 2019년 02월 2019년 03월 2019년 04월 2019년 05월 2019년 06월 2019년 07월  \
# 성별
# 계    계    306876    284101    301289    310462    315135    306275    324337
# 남   소계     98519     91918     97298    100294    102198     98845    104577
# 남   외래     97539     91000     96362     99313    101178     97830    103565
# 남   입원      1263      1112      1157      1250      1324      1270      1317
# 여   소계    208357    192183    203991    210168    212937    207430    219760
# 여   외래    207345    191281    203119    209239    211947    206455    218745
# 여   입원      1619      1310      1377      1530      1601      1586      1696
#
# 5  2019년 08월 2019년 09월  ... 2019년 11월 2019년 12월 2020년 01월 2020년 02월 2020년 03월  \
# 성별                      ...
# 계     320453    317401  ...    325566    328764    323442    314895    317522
# 남     103582    101763  ...    104088    104970    103532    101145    101578
# 남     102585    100797  ...    103090    104010    102571    100289    100784
# 남       1247      1220  ...      1245      1171      1222      1042       933
# 여     216871    215638  ...    221478    223794    219910    213750    215944
# 여     215868    214671  ...    220468    222807    218901    212929    215181
# 여       1583      1538  ...      1651      1594      1566      1207      1100
#
# 5  2020년 04월 2020년 05월 2020년 06월 2020년 07월 2020년 08월
# 성별
# 계     319785    331269    338264    347030    335517
# 남     101660    105185    107249    109810    106387
# 남     100950    104406    106437    108989    105622
# 남        881       970      1024      1020       970
# 여     218125    226084    231015    237220    229130
# 여     217371    225297    230211    236325    228324
# 여       1094      1197      1307      1430      1276
#
# [7 rows x 21 columns]

# %%
cond4.reset_index()
# Out:
# 5  index 성별  유형 2019년 01월 2019년 02월 2019년 03월 2019년 04월 2019년 05월 2019년 06월  \
# 0      0  계   계    306876    284101    301289    310462    315135    306275
# 1      1  남  소계     98519     91918     97298    100294    102198     98845
# 2      2  남  외래     97539     91000     96362     99313    101178     97830
# 3      3  남  입원      1263      1112      1157      1250      1324      1270
# 4      4  여  소계    208357    192183    203991    210168    212937    207430
# 5      5  여  외래    207345    191281    203119    209239    211947    206455
# 6      6  여  입원      1619      1310      1377      1530      1601      1586
#
# 5 2019년 07월  ... 2019년 11월 2019년 12월 2020년 01월 2020년 02월 2020년 03월 2020년 04월  \
# 0    324337  ...    325566    328764    323442    314895    317522    319785
# 1    104577  ...    104088    104970    103532    101145    101578    101660
# 2    103565  ...    103090    104010    102571    100289    100784    100950
# 3      1317  ...      1245      1171      1222      1042       933       881
# 4    219760  ...    221478    223794    219910    213750    215944    218125
# 5    218745  ...    220468    222807    218901    212929    215181    217371
# 6      1696  ...      1651      1594      1566      1207      1100      1094
#
# 5 2020년 05월 2020년 06월 2020년 07월 2020년 08월
# 0    331269    338264    347030    335517
# 1    105185    107249    109810    106387
# 2    104406    106437    108989    105622
# 3       970      1024      1020       970
# 4    226084    231015    237220    229130
# 5    225297    230211    236325    228324
# 6      1197      1307      1430      1276
#
# [7 rows x 23 columns]

# %%
cond4.reset_index()
# Out:
# 5     성별  유형 2019년 01월 2019년 02월 2019년 03월 2019년 04월 2019년 05월 2019년 06월  \
# index
# 0      계   계    306876    284101    301289    310462    315135    306275
# 1      남  소계     98519     91918     97298    100294    102198     98845
# 2      남  외래     97539     91000     96362     99313    101178     97830
# 3      남  입원      1263      1112      1157      1250      1324      1270
# 4      여  소계    208357    192183    203991    210168    212937    207430
# 5      여  외래    207345    191281    203119    209239    211947    206455
# 6      여  입원      1619      1310      1377      1530      1601      1586
#
# 5     2019년 07월 2019년 08월  ... 2019년 11월 2019년 12월 2020년 01월 2020년 02월  \
# index                      ...
# 0        324337    320453  ...    325566    328764    323442    314895
# 1        104577    103582  ...    104088    104970    103532    101145
# 2        103565    102585  ...    103090    104010    102571    100289
# 3          1317      1247  ...      1245      1171      1222      1042
# 4        219760    216871  ...    221478    223794    219910    213750
# 5        218745    215868  ...    220468    222807    218901    212929
# 6          1696      1583  ...      1651      1594      1566      1207
#
# 5     2020년 03월 2020년 04월 2020년 05월 2020년 06월 2020년 07월 2020년 08월
# index
# 0        317522    319785    331269    338264    347030    335517
# 1        101578    101660    105185    107249    109810    106387
# 2        100784    100950    104406    106437    108989    105622
# 3           933       881       970      1024      1020       970
# 4        215944    218125    226084    231015    237220    229130
# 5        215181    217371    225297    230211    236325    228324
# 6          1100      1094      1197      1307      1430      1276
#
# [7 rows x 22 columns]

# %%
a_total=cond4.iloc[0,2:].astype(int)
m_total=cond4.iloc[1,2:].astype(int)
w_total=cond4.iloc[4,2:].astype(int)

a_total.plot()
m_total.plot()
w_total.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-371-ad4b335bae63> in <module>
#       7 w_total.plot()
#       8
# ----> 9 a_total.barplot()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'barplot'

# %%
g=sns.FacetGrid(cond4,col="species",hue="species")
g.map(plt.hist,"sepal_length")

# %%
m_total=cond4.loc[1,]
w_total=cond4.loc[4,]

#a_total.plot()
cond4.loc[0,1:]

#a_total=sns.barplot(data=a_total, x="",y="주민등록인구수", estimator=sum).set_title("ddd")

#save_img=pop_15to19plot.get_figure()
#save_img.savefig('E:/kim_jiwon/src/project_01/data/img/population_15_19.png')

# %%
plt.figure(figsize=(18,3))
sns.heatmap(cond4.loc[[1],"2019년 01월":"2020년 08월"].astype(int), annot=True, cmap="Blues",
           fmt=".0f", annot_kws={'size':8})
# Out:
# <AxesSubplot:xlabel='5'>

# %% [markdown]
# # 주관적 정신건강 수준

# %%
import pandas as pd
mental=pd.read_csv('E:/kim_jiwon/src/Project_02/data/주관적인_정신건강_수준_20210412155804.csv',sep=',',encoding='cp949')
mental
# Out:
#     특성별(1)       특성별(2)                2017              2017.1  \
# 0   특성별(1)       특성별(2)  나는 밝고 즐거운 기분임을 느낀다  나는 밝고 즐거운 기분임을 느낀다
# 1   특성별(1)       특성별(2)           전혀 그렇지 않다             때때로 그렇다
# 2       전체           소계                 1.2                16.4
# 3       성별           남자                 0.9                16.4
# 4       성별           여자                 1.6                16.5
# 5      연령별      만15-18세                 0.2                 9.0
# 6      연령별      만19-29세                 1.5                15.8
# 7      연령별      만30-39세                 1.2                19.2
# 8      연령별      만18-19세                   -                   -
# 9      연령별      만20-24세                   -                   -
# 10     연령별      만25-29세                   -                   -
# 11     연령별      만30-34세                   -                   -
# 12     지역별           서울                 0.6                15.4
# 13     지역별        인천·경기                 1.3                18.8
# 14     지역별  대전·충청·세종·강원                 1.5                16.3
# 15     지역별     광주·전라·제주                 0.9                14.0
# 16     지역별     부산·울산·경남                 1.3                13.9
# 17     지역별        대구·경북                 2.0                17.4
# 18     학력별       중·고등학생                 0.3                 8.4
# 19     학력별     대학생·대학원생                 0.3                15.3
# 20     학력별         고졸이하                 2.3                18.3
# 21     학력별         대졸이상                 1.3                18.1
# 22   주거형태별           동거                 1.0                14.8
# 23   주거형태별       비동거·독립                 1.4                18.1
#
#                 2017.2              2017.3              2017.4  \
# 0   나는 밝고 즐거운 기분임을 느낀다  나는 밝고 즐거운 기분임을 느낀다  나는 밝고 즐거운 기분임을 느낀다
# 1       2주의 절반 이하는 그렇다      2주의 절반 이상은 그렇다             대부분 그렇다
# 2                 13.2                31.3                34.4
# 3                 13.9                30.7                34.0
# 4                 12.4                32.0                34.9
# 5                 11.2                28.3                43.9
# 6                 13.7                29.7                36.0
# 7                 13.2                33.9                30.0
# 8                    -                   -                   -
# 9                    -                   -                   -
# 10                   -                   -                   -
# 11                   -                   -                   -
# 12                13.9                35.0                32.3
# 13                11.5                34.7                30.1
# 14                 9.9                23.2                43.7
# 15                16.7                28.4                37.7
# 16                13.3                35.8                32.5
# 17                18.0                19.4                39.5
# 18                12.0                28.5                43.5
# 19                13.1                29.5                37.8
# 20                16.3                29.0                31.9
# 21                12.1                33.9                31.8
# 22                13.8                30.2                36.1
# 23                12.5                32.5                32.7
#
#                 2017.5            2017.6            2017.7  ...  \
# 0   나는 밝고 즐거운 기분임을 느낀다  나는 차분하고 편안함을 느낀다  나는 차분하고 편안함을 느낀다  ...
# 1               항상 그렇다         전혀 그렇지 않다           때때로 그렇다  ...
# 2                  3.4               2.2              15.0  ...
# 3                  4.1               1.5              15.2  ...
# 4                  2.7               2.9              14.8  ...
# 5                  7.4               1.0               9.7  ...
# 6                  3.3               2.5              14.7  ...
# 7                  2.5               2.3              16.9  ...
# 8                    -                 -                 -  ...
# 9                    -                 -                 -  ...
# 10                   -                 -                 -  ...
# 11                   -                 -                 -  ...
# 12                 2.7               1.8              14.5  ...
# 13                 3.5               2.9              16.0  ...
# 14                 5.4               1.6              15.7  ...
# 15                 2.3               1.4              13.9  ...
# 16                 3.2               1.7              12.4  ...
# 17                 3.7               3.1              17.2  ...
# 18                 7.3               1.0               8.9  ...
# 19                 4.1               1.6              15.2  ...
# 20                 2.2               3.9              16.4  ...
# 21                 2.8               1.9              15.9  ...
# 22                 4.1               1.7              13.9  ...
# 23                 2.8               2.7              16.2  ...
#
#                         2020.20                      2020.21  \
# 0   나는 잠에서 깨었을 때 피로가 다 가시고 상쾌했다  나는 잠에서 깨었을 때 피로가 다 가시고 상쾌했다
# 1                2주의 절반 이하는 그렇다               2주의 절반 이상은 그렇다
# 2                          12.9                         22.3
# 3                          13.4                         21.8
# 4                          12.4                         22.8
# 5                             -                            -
# 6                             -                            -
# 7                             -                            -
# 8                          11.5                         24.8
# 9                          13.6                         19.8
# 10                         12.0                         24.4
# 11                         13.8                         21.6
# 12                         13.9                         23.2
# 13                         13.1                         22.6
# 14                         12.3                         22.9
# 15                         11.9                         21.9
# 16                          9.4                         14.5
# 17                         17.6                         30.2
# 18                            -                            -
# 19                         11.3                         21.1
# 20                         13.5                         23.3
# 21                         13.4                         22.2
# 22                         13.3                         22.3
# 23                         12.2                         22.2
#
#                         2020.22                      2020.23  \
# 0   나는 잠에서 깨었을 때 피로가 다 가시고 상쾌했다  나는 잠에서 깨었을 때 피로가 다 가시고 상쾌했다
# 1                       대부분 그렇다                       항상 그렇다
# 2                          34.6                          7.1
# 3                          34.7                          7.7
# 4                          34.4                          6.4
# 5                             -                            -
# 6                             -                            -
# 7                             -                            -
# 8                          35.7                         11.2
# 9                          37.1                          7.2
# 10                         33.1                          6.5
# 11                         33.3                          6.3
# 12                         37.4                          7.3
# 13                         30.4                          6.8
# 14                         27.3                          7.9
# 15                         37.7                          6.9
# 16                         42.3                          7.8
# 17                         38.6                          5.8
# 18                            -                            -
# 19                         39.4                          9.2
# 20                         34.1                          7.6
# 21                         32.5                          5.7
# 22                         35.0                          7.4
# 23                         33.8                          6.6
#
#                     2020.24                  2020.25                  2020.26  \
# 0   나의 일상은 흥미로운 것들로 가득 차 있다  나의 일상은 흥미로운 것들로 가득 차 있다  나의 일상은 흥미로운 것들로 가득 차 있다
# 1                 전혀 그렇지 않다                  때때로 그렇다           2주의 절반 이하는 그렇다
# 2                       6.3                     23.2                     15.4
# 3                       7.0                     23.6                     14.8
# 4                       5.6                     22.7                     16.0
# 5                         -                        -                        -
# 6                         -                        -                        -
# 7                         -                        -                        -
# 8                       3.6                     20.3                     16.4
# 9                       5.5                     25.6                     13.9
# 10                      7.4                     22.2                     14.7
# 11                      6.9                     22.7                     17.2
# 12                      6.2                     15.2                     14.8
# 13                      6.6                     27.6                     15.2
# 14                      6.2                     20.1                     14.9
# 15                     13.0                     26.8                     14.4
# 16                      4.1                     26.3                     14.7
# 17                      2.1                     21.9                     20.0
# 18                        -                        -                        -
# 19                      4.2                     25.4                     12.9
# 20                      6.6                     20.7                     16.3
# 21                      7.2                     23.6                     16.0
# 22                      6.4                     23.3                     15.7
# 23                      6.3                     23.0                     14.7
#
#                     2020.27                  2020.28                  2020.29
# 0   나의 일상은 흥미로운 것들로 가득 차 있다  나의 일상은 흥미로운 것들로 가득 차 있다  나의 일상은 흥미로운 것들로 가득 차 있다
# 1            2주의 절반 이상은 그렇다                  대부분 그렇다                   항상 그렇다
# 2                      22.2                     26.9                      6.0
# 3                      21.6                     26.2                      6.8
# 4                      23.0                     27.7                      5.1
# 5                         -                        -                        -
# 6                         -                        -                        -
# 7                         -                        -                        -
# 8                      24.5                     27.6                      7.6
# 9                      20.8                     27.4                      6.7
# 10                     22.7                     27.2                      5.7
# 11                     22.3                     25.9                      5.1
# 12                     27.0                     30.3                      6.5
# 13                     20.2                     24.5                      5.9
# 14                     23.5                     27.5                      7.8
# 15                     16.8                     25.3                      3.6
# 16                     19.8                     30.8                      4.4
# 17                     25.9                     22.5                      7.6
# 18                        -                        -                        -
# 19                     22.5                     29.0                      6.1
# 20                     22.8                     26.6                      7.1
# 21                     21.7                     26.1                      5.3
# 22                     22.4                     25.9                      6.3
# 23                     21.9                     28.6                      5.5
#
# [24 rows x 122 columns]

# %% [markdown]
# # 지출목적별 소비자물가지수

# %%
import pandas as pd
cpi=pd.read_csv('E:/kim_jiwon/src/Project_02/data/지출목적별_소비자물가지수_품목_포함__2015100__20210412154851.csv',sep=',',encoding='cp949')
cpi1=cpi.iloc[:,1].to_frame()
cpi2=cpi.loc[:,'2018. 01':]
cpi3=pd.concat([cpi1,cpi2],axis=1)
cpi3

#cpi
# Out:
#                   지출목적별  2018. 01  2018. 02  2018. 03  2018. 04  2018. 05  \
# 0                 0 총지수    103.42    104.21    104.10    104.29    104.34
# 1        01 식료품 · 비주류음료    106.00    109.07    107.32    107.86    106.85
# 2            02 주류 및 담배    102.48    102.58    102.39    102.52    102.37
# 3            03 의류 및 신발    103.34    103.96    104.05    104.06    104.08
# 4   04 주택 ·수도 · 전기 및 연료    101.06    101.63    101.80    101.78    101.76
# 5      05 가정용품 및 가사 서비스    103.50    104.33    105.08    104.60    105.36
# 6                 06 보건    102.51    102.55    102.65    102.21    102.19
# 7                 07 교통    102.80    103.07    103.00    102.72    103.63
# 8                 08 통신     99.89     99.76     99.67    100.15    100.04
# 9            09 오락 및 문화    100.45    101.87    101.56    103.14    103.33
# 10                10 교육    103.40    103.69    103.99    104.20    104.24
# 11           11 음식 및 숙박    106.55    106.94    107.29    107.70    108.07
# 12       12 기타 상품 및 서비스    106.11    106.52    106.77    107.03    106.98
#
#     2018. 06  2018. 07  2018. 08  2018. 09  ...  2020. 06  2020. 07  2020. 08  \
# 0     104.13    103.93    104.85    105.65  ...    104.87    104.86    105.50
# 1     105.48    105.80    111.34    115.20  ...    111.18    111.28    114.78
# 2     102.34    102.54    102.52    102.45  ...    103.44    103.45    103.44
# 3     104.10    103.98    103.98    104.05  ...    104.79    105.20    105.10
# 4     101.68    100.08    100.33    102.04  ...    103.67    101.18    101.53
# 5     104.93    105.39    105.33    105.07  ...    106.98    107.13    107.41
# 6     102.36    101.32    101.37    101.32  ...    103.97    103.88    103.86
# 7     104.34    104.26    104.53    104.68  ...     97.54     99.60     99.84
# 8      99.94     99.39     99.29     99.21  ...     96.87     96.78     96.71
# 9     101.41    103.05    103.81    103.93  ...    100.37    101.77    102.78
# 10    104.26    104.28    104.38    104.46  ...    102.36    102.44    102.48
# 11    108.17    108.52    108.76    108.58  ...    110.95    111.13    111.35
# 12    107.13    106.85    107.12    107.24  ...    110.81    111.09    110.98
#
#     2020. 09  2020. 10  2020. 11  2020. 12  2021. 01  2021. 02  2021. 03
# 0     106.20    105.61    105.50    105.67    106.47    107.00    107.16
# 1     119.68    119.82    115.35    115.79    118.04    120.97    120.61
# 2     103.39    103.52    103.45    103.38    103.58    103.54    103.43
# 3     105.17    105.23    105.38    105.43    105.12    105.34    105.05
# 4     103.23    103.54    103.46    103.58    103.60    104.18    104.48
# 5     106.47    107.56    107.14    107.45    108.53    107.94    107.19
# 6     103.80    103.97    103.95    103.82    104.83    104.81    104.91
# 7      99.38     99.04     98.71     99.71    102.01    102.70    104.04
# 8      96.63     83.33     94.99     95.80     94.88     94.89     94.95
# 9     101.76    102.34    100.67    100.00    101.04     99.88     99.80
# 10    101.35    101.44    101.56    100.91    101.10    101.26    101.45
# 11    111.25    111.51    111.41    111.67    111.96    112.26    112.42
# 12    111.53    110.99    111.24    111.13    112.26    112.14    112.37
#
# [13 rows x 40 columns]

# %%
cpi3=cpi3.melt(id_vars="지출목적별",
        var_name="연도월",
        value_name="소비자물가지수")
cpi3
# Out:
#                    지출목적별       연도월  소비자물가지수
# 0                  0 총지수  2018. 01   103.42
# 1         01 식료품 · 비주류음료  2018. 01   106.00
# 2             02 주류 및 담배  2018. 01   102.48
# 3             03 의류 및 신발  2018. 01   103.34
# 4    04 주택 ·수도 · 전기 및 연료  2018. 01   101.06
# ..                   ...       ...      ...
# 502                08 통신  2021. 03    94.95
# 503           09 오락 및 문화  2021. 03    99.80
# 504                10 교육  2021. 03   101.45
# 505           11 음식 및 숙박  2021. 03   112.42
# 506       12 기타 상품 및 서비스  2021. 03   112.37
#
# [507 rows x 3 columns]

# %%
cpi3.info(0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   지출목적별    507 non-null    object
#  1   연도월      507 non-null    object
#  2   소비자물가지수  507 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 12.0+ KB

# %%
plt.figure(figsize=(18,8))
sns.pointplot(x="연도월", y="소비자물가지수", hue="지출목적별", data=cpi3)
# Out:
# <AxesSubplot:xlabel='연도월', ylabel='소비자물가지수'>

# %%
cpi3.pivot_table(index='연도월',columns='지출목적별',values='소비자물가지수').plot(figsize=(16,8))
plt.legend(bbox_to_anchor=(1.01,1),loc=0,borderaxespad=0)
plt.savefig('E:/kim_jiwon/src/project_02/img/cpi.png')
